# %%
# import the packages
# read the data
# divide into cat and numer using method
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file_path=r"C:\Users\omkar\OneDrive\Documents\Data science\Naresh IT\Naresh IT\Datafiles\\Visadataset.csv"
visa_df=pd.read_csv(file_path)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
cat_cols=visa_df.select_dtypes(include='object').columns
num_cols=visa_df.select_dtypes(exclude='object').columns

# %%
cat_cols
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
num_cols
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %% [markdown]
# **Continent**

# %%
visa_df['continent']
# Out:
# 0          Asia
# 1          Asia
# 2          Asia
# 3          Asia
# 4        Africa
#           ...
# 25475      Asia
# 25476      Asia
# 25477      Asia
# 25478      Asia
# 25479      Asia
# Name: continent, Length: 25480, dtype: object

# %% [markdown]
# **how to convert series to array**

# %%
visa_df['continent'].values
# Out:
# array(['Asia', 'Asia', 'Asia', ..., 'Asia', 'Asia', 'Asia'], dtype=object)

# %%
len(visa_df['continent'].values)
# Out:
# 25480

# %% [markdown]
# **unique**

# %%
visa_df['continent'].unique()
# it will number of unique continents
# Out:
# array(['Asia', 'Africa', 'North America', 'Europe', 'South America',
#        'Oceania'], dtype=object)

# %% [markdown]
# **nunique**

# %%
visa_df['continent'].nunique()
# Out:
# 6

# %% [markdown]
# **task**
#
# - i want to know how many members are from asia
#
# - i want to know how many members are from africa

# %%
con=visa_df['continent']=='Asia'
len(visa_df[con])
# Out:
# 16861

# %%
con=visa_df['continent']=='Asia'
len(visa_df[con])

con=visa_df['continent']=='Africa'
len(visa_df[con])

con=visa_df['continent']=='North America'
len(visa_df[con])

con=visa_df['continent']=='Europe'
len(visa_df[con])

con=visa_df['continent']=='South America'
len(visa_df[con])

con=visa_df['continent']=='Oceania'
len(visa_df[con])


con=visa_df['continent']==i
len(visa_df[con])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 20
#      16 con=visa_df['continent']=='Oceania'
#      17 len(visa_df[con])
# ---> 20 con=visa_df['continent']==i
#      21 len(visa_df[con])
#
# NameError: name 'i' is not defined

# %%
lables=visa_df['continent'].unique()
for i in lables:
    con=visa_df['continent']==i
    count=len(visa_df[con])
    print(f"the number of applicants from {i} is:{count}")
# Out:
# the number of applicants from Asia is:16861
# the number of applicants from Africa is:551
# the number of applicants from North America is:3292
# the number of applicants from Europe is:3732
# the number of applicants from South America is:852
# the number of applicants from Oceania is:192

# %% [markdown]
# **create a dataframe**
#
# - we need two lists
#
# - alreday lables list available
#
# - modify above code take empty list append the count values in that list

# %%
lables=visa_df['continent'].unique()
count=[]
for i in lables:
    con=visa_df['continent']==i
    count.append(len(visa_df[con]))
print(lables)
print(count)

pd.DataFrame(zip(lables,count),
             columns=['Continent','Number of Applicants'])
# Out:
# ['Asia' 'Africa' 'North America' 'Europe' 'South America' 'Oceania']
# [16861, 551, 3292, 3732, 852, 192]
#        Continent  Number of Applicants
# 0           Asia                 16861
# 1         Africa                   551
# 2  North America                  3292
# 3         Europe                  3732
# 4  South America                   852
# 5        Oceania                   192

# %% [markdown]
# **value counts**

# %%
visa_df['continent'].value_counts()
# Out:
# continent
# Asia             16861
# Europe            3732
# North America     3292
# South America      852
# Africa             551
# Oceania            192
# Name: count, dtype: int64

# %% [markdown]
# - we performed the frequency table on categorical columns
#
# - we did from scratch
#
# - we also have **value_counts**
#
# - value_counts output represent as series

# %%
continent_vc=visa_df['continent'].value_counts()
keys=continent_vc.keys()
values=continent_vc.values
pd.DataFrame(zip(keys,values),
            columns=['Continent','No of Applicants'])
# Out:
#        Continent  No of Applicants
# 0           Asia             16861
# 1         Europe              3732
# 2  North America              3292
# 3  South America               852
# 4         Africa               551
# 5        Oceania               192

# %%
lables=visa_df['continent'].unique()
count=[]
for i in lables:
    con=visa_df['continent']==i
    count.append(len(visa_df[con]))
print(lables)
print(count)

pd.DataFrame(zip(lables,count),
             columns=['Continent','Number of Applicants'])

#########################################################
continent_vc=visa_df['continent'].value_counts()
keys=continent_vc.keys()
values=continent_vc.values
pd.DataFrame(zip(keys,values),
            columns=['Continent','No of Applicants'])

# %%
cat_cols
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %% [markdown]
# - we have total 9 catcols
#
# - we will create a folder with name **freq_tables**
#
# - we will use any method create a function
#
# - if we call that function all the 9 tables should save in **freq_table folder**
#
# - file_name: column_name.csv
#
# - column name :
#
#     - Lable
#
#     - Count

# %%
for i in cat_cols:
    name=f"{i}.csv"
    new_dir=<till your frq_table>
    path=os.path.jon(new_dir,name)
    print(path)
# Out:
# case_id.csv
# continent.csv
# education_of_employee.csv
# has_job_experience.csv
# requires_job_training.csv
# region_of_employment.csv
# unit_of_wage.csv
# full_time_position.csv
# case_status.csv

# %%
import os
new_folder='freq_tables'
os.mkdir(new_folder) # where this will create?
cwd=os.getcwd()
print(cwd)

C:\Users\niran\Documents\NareshIT\DataAnalysis\Pandas\'freq_tables\cont.csv

# %% [markdown]
# **step-1: create a folder**

# %%
import os
folder_name='freq_table'
try:
   os.makedirs(folder_name)
except Exception as e:
    print(e)

# %% [markdown]
# **step-2: jon cwd with new_folder**

# %%
cwd=os.getcwd()
new_dir=os.path.join(cwd,folder_name)
new_dir
# Out:
# 'C:\\Users\\omkar\\OneDrive\\Documents\\Data science\\Naresh IT\\Naresh IT\\Data science\\Batches\\Batch_11_Oct\\Data analysis\\freq_table'

# %% [markdown]
# **step-3:Join the new dir with column name.csv**

# %%
for i in cat_cols[1:]:
    new_path=os.path.join(new_dir,f'{i}.csv')
    print(new_path)
# Out:
# C:\Users\omkar\OneDrive\Documents\Data science\Naresh IT\Naresh IT\Data science\Batches\Batch_11_Oct\Data analysis\freq_table\continent.csv
# C:\Users\omkar\OneDrive\Documents\Data science\Naresh IT\Naresh IT\Data science\Batches\Batch_11_Oct\Data analysis\freq_table\education_of_employee.csv
# C:\Users\omkar\OneDrive\Documents\Data science\Naresh IT\Naresh IT\Data science\Batches\Batch_11_Oct\Data analysis\freq_table\has_job_experience.csv
# C:\Users\omkar\OneDrive\Documents\Data science\Naresh IT\Naresh IT\Data science\Batches\Batch_11_Oct\Data analysis\freq_table\requires_job_training.csv
# C:\Users\omkar\OneDrive\Documents\Data science\Naresh IT\Naresh IT\Data science\Batches\Batch_11_Oct\Data analysis\freq_table\region_of_employment.csv
# C:\Users\omkar\OneDrive\Documents\Data science\Naresh IT\Naresh IT\Data science\Batches\Batch_11_Oct\Data analysis\freq_table\unit_of_wage.csv
# ...

# %% [markdown]
# **step-4:append the dataframes**
#
# - paths are ready
#
# - we know how to create dataframe

# %%
for i in cat_cols[1:]:
    vc=visa_df[i].value_counts()
    keys=vc.keys()
    values=vc.values
    df=pd.DataFrame(zip(keys,values),
                columns=['Label','No of Applicants'])
    new_path=os.path.join(new_dir,f'{i}.csv')
    df.to_csv(new_path,index=False)

# %%
import os
folder_name='freq_table'
try:
   os.makedirs(folder_name)
except Exception as e:
    print(e)

cwd=os.getcwd()
new_dir=os.path.join(cwd,folder_name)

for i in cat_cols[1:]:
    vc=visa_df[i].value_counts()
    keys=vc.keys()
    values=vc.values
    df=pd.DataFrame(zip(keys,values),
                columns=['Label','No of Applicants'])
    new_path=os.path.join(new_dir,f'{i}.csv')
    df.to_csv(new_path,index=False)
# Out:
# [WinError 183] Cannot create a file when that file already exists: 'freq_table'

# %% [markdown]
# **Bar chart**
#
# - in matplotlib we have a method plt.bar
#
# - we know that in order to get bar plot need two columns
#
#   - categorical column which indicates lables
#
#   - numerical column which indicates corresponding values
#
# - bar chart we will get from frquency table
#
# - from there we extract labels and values
#
# - value_counts will give lables and values

# %%
labels=visa_df['continent'].value_counts().keys()
values=visa_df['continent'].value_counts().values
plt.figure(figsize=(10,6)) # 10 untis x-axis, 6 units y-axis
plt.bar(labels,values)
plt.xlabel('Labels') # X-axis name
plt.ylabel('Count') # Y-axis name
plt.title('Continent_Bar_chart') # Title of the plot
plt.savefig('Continent_Bar_chart.jpg')
plt.show()  # write up will not come, show always at last

# %%
# reacap
# import the package
# read the data and plot bar charts
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

file_path=r"C:\Users\omkar\OneDrive\Documents\Data science\Naresh IT\Naresh IT\Datafiles\\Visadataset.csv"
visa_df=pd.read_csv(file_path)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
labels=visa_df['continent'].value_counts().keys()
values=visa_df['continent'].value_counts().values
plt.figure(figsize=(10,6)) # 10 untis x-axis, 6 units y-axis
plt.bar(labels,values)
plt.xlabel('Labels') # X-axis name
plt.ylabel('Count') # Y-axis name
plt.title('Continent_Bar_chart') # Title of the plot
plt.savefig('Continent_Bar_chart.jpg')
plt.show()  # write up will not come, show always at last

# %% [markdown]
# **subplots**

# %% [markdown]
# - we can plot the many plots in one lay out
#
# - suppose we have 25 plots to show
#
# - instead of showing one by one
#
# - we can show the plots using subplot as matrix type
#
# - subplot method avilable in matplotlib pacakge

# %%
plt.subplot(2,2,1)
plt.subplot(2,2,2)
plt.subplot(2,2,3)
plt.subplot(2,2,4)
# Out:
# <Axes: >

# %%
plt.subplot(2,2,1)
plt.subplot(2,2,2)
plt.subplot(2,2,3)
plt.subplot(2,2,4)

plt.subplot(2,2,i)

# %%
for i in range(4):
    plt.subplot(2,2,i+1)

# %%
# (1,2) means 1 row and 2 columns
plt.subplot(1,2,1)
plt.subplot(1,2,2)
# Out:
# <Axes: >

# %%
# (2,1) means 2 rows and 1 column
plt.subplot(2,1,1)
plt.subplot(2,1,2)
# Out:
# <Axes: >

# %%
# other than caseid we have 8 columns
# (2,4)   (4,2)  (8,1)  (1,8)  (3,3)
# by using for loop make 3,3 total 9 plots
cat_cols=visa_df.select_dtypes(include='object').columns
num_cols=visa_df.select_dtypes(exclude='object').columns
n=len(cat_cols)-1
for i in range(n):
    # i=0
    plt.subplot(3,3,i+1)  #(3,3,1) correct
    plt.title(f'{cat_cols[i+1]}') # cat_cols[0]: cases_id

# %%
n=len(cat_cols)-1  # n=8
for i in range(n):
    print(cat_cols[i+1],end=' ')

# we are adding two times i+1
# because for loop starts from 0 to 7
# subplots starts from 3,3,1   3,3,i+1
# cat cols            cat_cols[i=0]   cat_cols[i+1]
# Out:
# continent education_of_employee has_job_experience requires_job_training region_of_employment unit_of_wage full_time_position case_status

# %%
cat_cols=visa_df.select_dtypes(include='object').columns
num_cols=visa_df.select_dtypes(exclude='object').columns
n=len(cat_cols)  # n=9
plt.figure(figsize=(28,14))
for i in range(1,n): # loop runs 8 times
    labels=visa_df[cat_cols[i]].value_counts().keys()
    values=visa_df[cat_cols[i]].value_counts().values
    plt.subplot(3,3,i)
    plt.bar(labels,values)
    plt.xlabel(Labels')
    plt.ylabel('Count') 
    plt.title(f'{cat_cols[i]}_Bar_chart') #


# dont show here

# %%
for i,j in enumerate(cat_cols):
    print(i,j)
# Out:
# 0 case_id
# 1 continent
# 2 education_of_employee
# 3 has_job_experience
# 4 requires_job_training
# 5 region_of_employment
# 6 unit_of_wage
# 7 full_time_position
# 8 case_status

# %% [markdown]
# **pie chart**
#
# - pie chart is avalaible at matplotlib package
#
# - pie chart mainly takes two values
#
#     - keys
#
#     - values

# %%
visa_df['continent'].value_counts(normalize=True)
# Out:
# continent
# Asia             0.661735
# Europe           0.146468
# North America    0.129199
# South America    0.033438
# Africa           0.021625
# Oceania          0.007535
# Name: proportion, dtype: float64

# %%
keys=visa_df['continent'].value_counts().keys()
values=visa_df['continent'].value_counts().values

# %%
plt.pie(values,
        explode=[1,1,1,1,1,1],
        labels=keys,
       autopct="%0.3f%%",
       radius=0.5)   # 0.2f%= 66.17%
plt.show()

# repeat the pie charts for all 8 columns using subplot
# i will wait for whatsapp message screenshot
